# %%
# Importing libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
# Importing the development dataset

dataset = pd.read_csv('Basic Data.csv')
x = dataset.iloc[:, 2:-1]
y = dataset.iloc[:, -1]

# %%
# first 5 observations
dataset.head()
# Out:
#                 ID  Epitope       PP1       PP2       PP3       KF1        Z1  \
# 0  LDRLFNKKKELGQDK  E-10004  0.220667 -0.172667  0.055333 -0.175333  0.902667
# 1  LKLDRLFNKKKELGQ  E-10004  0.094000 -0.111333  0.106000 -0.283333  0.352000
# 2  NKYKLKLDRLFNKKK  E-10004  0.253333  0.012667  0.302000 -0.060667  0.516000
# 3  RLFNKKKELGQDKMQ  E-10004  0.211333 -0.133333  0.107333 -0.269333  0.849333
# 4  YKLKLDRLFNKKKEL  E-10004  0.161333  0.010000  0.152000 -0.280000  0.082000
#
#    F1        T1     VHSE1   ProtFP1       ST1   BLOSUM1   MSWHIM1     Class
# 0 NaN -3.556000 -0.412000 -2.104000 -0.693933  0.516667 -0.208667  Negative
# 1 NaN -3.538000 -0.244667 -1.279333 -0.688533  0.319333 -0.265333  Negative
# 2 NaN -2.651333 -0.360667 -1.461333 -0.530333  0.362000 -0.225333  Negative
# 3 NaN -3.426000 -0.422667 -1.970000 -0.668733  0.516000 -0.193333  Negative
# 4 NaN -2.664667 -0.204667 -0.759333 -0.534533  0.190000 -0.234000  Negative

# %%
# last 5 observations
dataset.tail()
# Out:
#                   ID  Epitope       PP1       PP2       PP3       KF1  \
# 344  PDVPYVKRVKTWRMH  E-10700 -0.013333 -0.054667  0.160667  0.158000
# 345  PKYHPDVPYVKRVKT  E-10700 -0.009333 -0.157333  0.180000  0.423333
# 346  VPYVKRVKTWRMHLF  E-10700 -0.142667  0.065333  0.177333 -0.101333
# 347  YHPDVPYVKRVKTWR  E-10700  0.062000 -0.028667  0.152667  0.343333
# 348  EDVQFADSRIRPQTI  E-10704  0.094000 -0.288667 -0.111333 -0.108667
#
#            Z1  F1        T1     VHSE1   ProtFP1       ST1   BLOSUM1   MSWHIM1  \
# 344 -0.134667 NaN -2.696667 -0.090667 -0.062667 -0.556533  0.096667 -0.245333
# 345 -0.016000 NaN -3.196667 -0.182667 -1.084000 -0.646267  0.257333 -0.248667
# 346 -0.856000 NaN -2.305333  0.163333  1.467333 -0.482467 -0.267333 -0.222667
# 347 -0.114000 NaN -2.286000 -0.117333 -0.194000 -0.489800  0.084667 -0.134000
# 348  0.582667 NaN -3.958667 -0.277333 -1.155333 -0.774133  0.340000 -0.265333
#
#         Class
# 344  Negative
# 345  Negative
# 346  Negative
# ...

# %%
# shape
dataset.shape
# Out:
# (349, 15)

# %%
# unique values per attribute
dataset.nunique()
# Out:
# ID         335
# Epitope     67
# PP1        284
# PP2        267
# PP3        262
# KF1        295
# Z1         315
# F1          18
# T1         315
# VHSE1      293
# ProtFP1    325
# ST1        328
# BLOSUM1    298
# MSWHIM1    265
# Class        2
# dtype: int64

# %%
# null values
dataset.isnull().sum()
# Out:
# ID           0
# Epitope      0
# PP1          0
# PP2          0
# PP3          0
# KF1          0
# Z1           0
# F1         330
# T1           0
# VHSE1        0
# ProtFP1      0
# ST1          0
# BLOSUM1      0
# MSWHIM1      0
# Class        0
# dtype: int64

# %%
dataset.isnull().sum().array
# Out:
# <PandasArray>
# [0, 0, 0, 0, 0, 0, 0, 330, 0, 0, 0, 0, 0, 0, 0]
# Length: 15, dtype: int64

# %%
# attribute names
dataset.columns
# Out:
# Index(['ID', 'Epitope', 'PP1', 'PP2', 'PP3', 'KF1', 'Z1', 'F1', 'T1', 'VHSE1',
#        'ProtFP1', 'ST1', 'BLOSUM1', 'MSWHIM1', 'Class'],
#       dtype='object')

# %%
# description
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349 entries, 0 to 348
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       349 non-null    object
#  1   Epitope  349 non-null    object
#  2   PP1      349 non-null    float64
#  3   PP2      349 non-null    float64
#  4   PP3      349 non-null    float64
#  5   KF1      349 non-null    float64
#  6   Z1       349 non-null    float64
#  7   F1       19 non-null     float64
#  8   T1       349 non-null    float64
#  9   VHSE1    349 non-null    float64
#  10  ProtFP1  349 non-null    float64
#  11  ST1      349 non-null    float64
#  12  BLOSUM1  349 non-null    float64
#  13  MSWHIM1  349 non-null    float64
#  14  Class    349 non-null    object
# dtypes: float64(12), object(3)
# memory usage: 41.0+ KB

# %%
# further description
dataset.describe()
# Out:
#               PP1         PP2         PP3         KF1          Z1         F1  \
# count  349.000000  349.000000  349.000000  349.000000  349.000000  19.000000
# mean    -0.033696   -0.352248   -0.023230   -0.126256    0.324816  -0.389705
# std      0.218198    0.121763    0.137459    0.292143    0.631943   0.171080
# min     -0.701333   -0.618000   -0.398667   -0.818000   -1.246000  -0.737533
# 25%     -0.162000   -0.432667   -0.122000   -0.325333   -0.077333  -0.516467
# 50%     -0.038667   -0.359333   -0.010000   -0.166667    0.342000  -0.407600
# 75%      0.100000   -0.274667    0.079333    0.022000    0.714000  -0.270300
# max      0.816667    0.065333    0.302000    0.807333    3.088000  -0.104067
#
#                T1       VHSE1     ProtFP1         ST1     BLOSUM1     MSWHIM1
# count  349.000000  349.000000  349.000000  349.000000  349.000000  349.000000
# mean    -4.644126   -0.120088   -0.846898   -0.871856    0.220036   -0.314115
# ...

# %%
# class attribute value counts
dataset.Class.value_counts()
# Out:
# Negative    322
# Positive     27
# Name: Class, dtype: int64

# %%
sns.pairplot(x)

# %%
dataset.PP1.hist(bins=50)

# %%
dataset.PP2.hist(bins=50)

# %%
dataset.PP3.hist(bins=50)

# %%
dataset.KF1.hist(bins=50)

# %%
dataset.Z1.hist(bins=50)

# %%
dataset.F1.hist(bins=50)

# %%
x.hist(bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000225C3E86310>,
# ...
#       dtype=object)

# %%
# variance of each data
x.var
# Out:
# <bound method DataFrame.var of           PP1       PP2       PP3       KF1        Z1  F1        T1     VHSE1  \
# 0    0.220667 -0.172667  0.055333 -0.175333  0.902667 NaN -3.556000 -0.412000
# 1    0.094000 -0.111333  0.106000 -0.283333  0.352000 NaN -3.538000 -0.244667
# 2    0.253333  0.012667  0.302000 -0.060667  0.516000 NaN -2.651333 -0.360667
# 3    0.211333 -0.133333  0.107333 -0.269333  0.849333 NaN -3.426000 -0.422667
# 4    0.161333  0.010000  0.152000 -0.280000  0.082000 NaN -2.664667 -0.204667
# ..        ...       ...       ...       ...       ...  ..       ...       ...
# 344 -0.013333 -0.054667  0.160667  0.158000 -0.134667 NaN -2.696667 -0.090667
# 345 -0.009333 -0.157333  0.180000  0.423333 -0.016000 NaN -3.196667 -0.182667
# 346 -0.142667  0.065333  0.177333 -0.101333 -0.856000 NaN -2.305333  0.163333
# 347  0.062000 -0.028667  0.152667  0.343333 -0.114000 NaN -2.286000 -0.117333
# 348  0.094000 -0.288667 -0.111333 -0.108667  0.582667 NaN -3.958667 -0.277333
#
# ...
